# %% [markdown]
# ## Practical lesson №8. Gaussian and Laplace pyramids of image

# %% [markdown]
# Gaussian bluring with fourier transform.

# %%
from skimage.io import imread, imshow
from skimage.filters import gaussian
from numpy.fft import fft2, fftshift, ifft2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
IMG = imread('palace.jpg', as_grey=True)
plt.figure(figsize=(15,10))
plt.subplot(121)
imshow(IMG)
plt.subplot(122)
FOURIER_IMG = fft2(IMG)
imshow(np.log(1 + abs(fftshift(FOURIER_IMG))))
# Out:
# /home/vasily/.virtualenvs/keras/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/vasily/.virtualenvs/keras/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)
# /home/vasily/.virtualenvs/keras/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:77: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   warn("Float image out of standard range; displaying "

# %%
filt_gauss = np.zeros(img.shape)
filt_gauss[img.shape[0] // 2, img.shape[1] // 2] = 1
IMG_GAUSS = gaussian(filt_gauss, sigma = 2)
FOURIER_GAUSS = fft2(IMG_GAUSS)

plt.figure(figsize=(15,10))
plt.subplot(121)
# imshow(filt_gauss)
imshow(IMG_GAUSS[img.shape[0] // 2 - 10:img.shape[0] // 2 + 10, img.shape[1] // 2 - 10: img.shape[1] // 2 + 10])
plt.subplot(122)
 
imshow(np.log(1 + abs(fftshift(FOURIER_GAUSS))))
# Out:
# /home/vasily/.virtualenvs/keras/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/vasily/.virtualenvs/keras/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:74: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "
# /home/vasily/.virtualenvs/keras/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
FOURIER_BLUR_IMG = abs(FOURIER_GAUSS) * FOURIER_IMG
plt.figure(figsize=(15,10))
plt.subplot(121)
imshow(np.log(1 + abs(fftshift(FOURIER_BLUR_IMG))))
plt.subplot(122)
blur_img = ifft2(FOURIER_BLUR_IMG)
imshow(blur_img.real)
# Out:
# /home/vasily/.virtualenvs/keras/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /home/vasily/.virtualenvs/keras/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:77: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   warn("Float image out of standard range; displaying "
# /home/vasily/.virtualenvs/keras/lib/python3.6/site-packages/matplotlib/axes/_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
blur_img
# Out:
# array([[0.38555661-1.27359073e-15j, 0.41626454-1.34564232e-15j,
#         0.43940964-9.51870752e-16j, ..., 0.3109496 +5.54595519e-17j,
#         0.32651025-3.70477675e-16j, 0.35318588-1.12189306e-15j],
#        [0.41472785-1.31655011e-15j, 0.43452802-1.36261852e-15j,
#         0.44767883-9.42656851e-16j, ..., 0.35519517-1.35492295e-16j,
#         0.36980829-5.81741755e-16j, 0.39140536-1.24569241e-15j],
#        [0.43137316-1.35107652e-15j, 0.44129052-1.34414408e-15j,
#         0.4460731 -8.83402143e-16j, ..., 0.39088877-2.36255357e-16j,
#         0.402374  -6.60622178e-16j, 0.4173345 -1.23719103e-15j],
#        ...,
#        [0.29485522-1.10117719e-15j, 0.331267  -1.23196556e-15j,
#         0.36265664-7.47979292e-16j, ..., 0.22976423+2.02771953e-16j,
#         0.23909659-2.03044653e-16j, 0.26155965-1.03963345e-15j],
#        [0.3172017 -1.16255893e-15j, 0.35799544-1.23624029e-15j,
#         0.39242162-8.12664887e-16j, ..., 0.24037351+3.67156919e-17j,
# ...

# %% [markdown]
# ## Task №1
# Build a Gaussian pyramid of the image with at least five layers.
# Visualize the resulting images and the frequency amplitudes on each level of the pyramid.
# Make sure that the frequency range is narrowed on each layer.
# Build a pyramid for three different values of the Sigma of the Gaussian nucleus.
# For the convenience of experimentation, define a separate function (build_gauss_pyramid) for building a Gaussian pyramid with the parameters img (the image on which the pyramid is built), sigma (the parameter of the Gaussian kernel), n_layers (the number of layers of the pyramid), which returns a list of required images.

# %%
def build_gauss_pyramid(img, sigma, n_layers):
    # code here
    return imgs, fouries

# %% [markdown]
# ## Task №2.
# Build a Laplacian pyramid of the image with at least five layers.
# The function for constructing the Laplace pyramid should use the function of constructing the Gaussian pyramid and have, like the function of the Gaussian pyramid, the parameters img, sigma and n_layers.

# %%
def build_laplas_pyramid(img, sigma, n_layers):
    # Code here
    return imgs, fouries_lap

# %% [markdown]
# ## Task №3.
# What levels of the Gaussian and Laplace pyramids need to be summed to get the original image?
# Find this levels, sum them and get the original image.
