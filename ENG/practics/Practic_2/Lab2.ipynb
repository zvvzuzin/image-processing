# %% [markdown]
# # Practical lesson №2

# %%
from skimage.io import imread, imshow, imsave
from skimage import img_as_float
import numpy as np
# %matplotlib inline

# %% [markdown]
# Task #1. Read the image from parrot.png. Calculate negative of the image.
# It means that pixels with 0 value should have value 255 and vice versa if your image has byte type.
#
# For example,
#
# Byte image: 255 -> 0, 0 -> 255, 1 -> 254, 240 -> 15, etc.
#
# Float image: 0 -> 1, 1 -> 0, 0.4 -> 0.6, etc.
#
# Show the image negative.

# %%
# Code here

# %% [markdown]
# You can read images directly via link. imread(link)
#
# Task #2. Read the image from link https://www.nastol.com.ua/pic/201210/1920x1200/nastol.com.ua-34781.jpg. In this image, swap the channels so that instead of the RGB order, the channels are in BRG order. Use the function dstack.

# %%
# Code here

# %% [markdown]
# Task #3. Read a color image from https://www.nastol.com.ua/pic/201210/1920x1200/nastol.com.ua-34781.jpg. Calculate the grayscale image of it. The resulting image must be single-channel. To calculate the gray channel, use the formula $Y=0.2126⋅R+0.7152⋅G+0.0722⋅B$. Do not forget to first convert the image to real numbers (img_as_float function), use transformation and after convert to integers (img_as_ubyte function).

# %%
# Code here

# %% [markdown]
# Task #4. Given a grayscale image of the moon surface. Plot histogram of this image.
# Apply different operaton for increasing and decreasing of contrast and brightness.
# Plot an image and its histogram after each operation by using subplot.

# %%
from skimage import data
img = data.moon()
print(img.shape)
imshow(img)
# Out:
# (512, 512)
