# %%
from skimage.io import imread, imsave, imshow
from skimage import img_as_ubyte
from skimage.transform import resize
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = imread('/media/vasily/586AD30E6AD2E830/datasets/DSB 2018/train/ef3ef194e5657fda708ecbd3eb6530286ed2ba23c88efb9f1715298975c73548/images/ef3ef194e5657fda708ecbd3eb6530286ed2ba23c88efb9f1715298975c73548.png', as_grey=True)
# imshow(img)
imshow(resize(img, (1000,1000)))
# img = 1 - img
# img = img_as_ubyte(img)
# img = img // 2 + 55
# Out:
# /home/vasily/.virtualenvs/cv/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
plt.hist(img.ravel(), bins = 255, range=[0, 1]);

# %%
imshow(img)
img.min(), img.max()
# Out:
# (0.11564509803921563, 0.84417921568627452)

# %%
img = img - img.min()
plt.hist(img.ravel(), bins = 255, range=[0, 1]);

# %%
img_new = img * 1 / (img.max() - img.min())
plt.hist(img_new.ravel(), bins = 255, range=[0, 1]);

# %%
imshow(img)

# %%
imshow(img_new)

# %%
img = imread('parrot.png')
imshow(img)

# %%
from skimage.color import rgb2hsv, hsv2rgb

# %%
img_new = rgb2hsv(img)
imshow(rgb2hsv(img)[:,:,0])
